# %% [markdown]
# ## Libraries

# %%
# data manipulation
import pandas as pd
import numpy as np

# path and files finder
from pathlib import Path
from os import listdir

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
cf.go_offline()

# utils
# %run Pickle_utils.ipynb # pickleUtilss

# %% [markdown]
# ## Open/preprocess data

# %%
# ?pickleUtilss

# %%
path = Path().resolve().parent / 'Pickles'/ 'K_may_ags_16_m_l_no_gplearn'
list_dir = listdir(path)
files = [ld for ld in list_dir if ld[-2:-1].isdigit()]

# %%
df_all = pickleUtilss.open_pickle(path, files)
df_join = pickleUtilss.join_pickle(df_all)
df_pred = pickleUtilss.concat_pred(df_join)
df_er = pickleUtilss.concat_error(df_join)

# %% [markdown]
# ## Plot

# %%
sm_er = (df_er[["14_04_2021_05_07_41", "14_04_2021_07_11_38", "14_04_2021_10_15_00", "14_04_2021_11_24_55"]]*100).mean()

# %%
sm_er
# Out:
# 14_04_2021_05_07_41    1.942904
# 14_04_2021_07_11_38    1.987259
# 14_04_2021_10_15_00    1.983828
# 14_04_2021_11_24_55    1.977753
# dtype: float64

# %%
df_pred[["real", "14_04_2021_05_07_41", "14_04_2021_07_11_38", "14_04_2021_10_15_00", "14_04_2021_11_24_55"]].iplot()
# Out:
# <div>
#
#
#             <div id="126159b9-32fc-459d-a3d8-b3369544e767" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("126159b9-32fc-459d-a3d8-b3369544e767")) {
#                     Plotly.newPlot(
#                         '126159b9-32fc-459d-a3d8-b3369544e767',
# ...

# %%
sm_er
# Out:
# 14_04_2021_05_07_41    1.942904
# 14_04_2021_07_11_38    1.987259
# 14_04_2021_10_15_00    1.983828
# 14_04_2021_11_24_55    1.977753
# dtype: float64

# %%
(df_er[["14_04_2021_05_07_41", "14_04_2021_07_11_38", "14_04_2021_10_15_00", "14_04_2021_11_24_55"]]*100).iplot()
# Out:
# <div>
#
#
#             <div id="bf02082a-966b-450c-8688-4c31a0b25271" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bf02082a-966b-450c-8688-4c31a0b25271")) {
#                     Plotly.newPlot(
#                         'bf02082a-966b-450c-8688-4c31a0b25271',
# ...

# %%
sm_er
# Out:
# 14_04_2021_05_07_41    1.942904
# 14_04_2021_07_11_38    1.987259
# 14_04_2021_10_15_00    1.983828
# 14_04_2021_11_24_55    1.977753
# dtype: float64

# %%
df_all["14_04_2021_05_07_41"][0]
# Out:
# {'kernel': 'rbf',
#  'C': 6.800161646208794,
#  'epsilon': 4.150571825462862,
#  'mu': 0.25443106017806894,
#  'lmbda': 0.1167079477454115,
#  'gamma': 0.08681154969020731}

# %%
df_all["14_04_2021_11_24_55"][0]
# Out:
# {'kernel': 'rbf',
#  'C': 6.764905818000578,
#  'epsilon': 4.2062454891211445,
#  'mu': 0.23831156597873923,
#  'lmbda': 0.07413572302346755,
#  'gamma': 0.09678630095093366}
