# %%
from gplearn.genetic import SymbolicTransformer
from gplearn.fitness import make_fitness
from gplearn.functions import make_function

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MaxAbsScaler
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %run ../../SVR_library/SVR_MAPE_Library.ipynb

# %% [markdown]
# ### Functions

# %%
# independent variables
def independent():
    # date dependent variables
    fecha = pd.DataFrame(consumo.index.year.values, index = consumo.index, columns = ["year"])
    fecha.year = fecha.year/fecha.year.max()
    fecha["week"] = consumo.index.week/53
    fecha["day"] = consumo.index.day/31
    fecha["dayofyear"] = consumo.index.dayofyear/366
    
    fecha["fin"]=consumo.index.weekday
    fecha["entre"]=consumo.index.weekday
    fecha["fin"]=fecha["fin"].replace([0,1,2,3,4,5,6],[.5,0,0,0,.5,1,1])
    fecha["entre"]=fecha["entre"].replace([0,1,2,3,4,5,6],[.5,1,1,1,.5,0,0])
    return fecha

# %%
# custom metric
def _mape(y, y_pred, w):
    diffs = np.abs(np.divide((np.maximum(0.001, y) - np.maximum(0.001, y_pred)),np.maximum(0.001, y)))
    
    return 100. * np.average(diffs, weights=w)

mape = make_fitness(_mape, greater_is_better=False)

# %% [markdown]
# ### Load

# %%
path_consumo = Path().resolve().parents[1] / "Data" / "Data1.xlsx"
consumo = pd.read_excel(path_consumo)
consumo = consumo.set_index("fecha").loc["2007-01-01":"2020-03-30"]

# %%
# X1 =  independent()

# %%
t = np.arange(1, consumo.size+1).reshape(-1, 1)
t_norm = t/t.max()

# %%
X_train, X_test, y_train1, y_test = train_test_split(t, consumo, test_size = 365, shuffle = False)

scaler = MaxAbsScaler(); scaler.fit(X_train); X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

scaler1 = MaxAbsScaler(); scaler1.fit(y_train1)
y_train = scaler1.transform(y_train1).reshape(-1)

# %% [markdown]
# ### model

# %%
function_set = ['add', 'sub', 'mul', 'div', 'sin', 'cos', 'abs']
model = SymbolicTransformer(generations=10, population_size=10000,
                         hall_of_fame=100, n_components=10, 
                         init_method = "half and half", p_hoist_mutation = 0.05,
                         p_crossover = 0.7, p_subtree_mutation = 0.2,
                         function_set=function_set, metric = mape,
                         parsimony_coefficient=0.0005,
                         max_samples=0.95, verbose=1,
                         random_state=0)
model.fit(X_train, y_train)
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    18.85          14055.4        7          6.76783          6.71235      3.96m
#    1     9.75          43.6029        6          6.73647          6.23201      2.84m
#    2    10.67          55.5528        8          6.69382          6.17705      2.61m
#    3    12.95          38.8569       10           6.5244           7.7643      2.36m
#    4    14.72          28.5939       11          6.56778          6.94152      2.18m
#    5    19.09          25.5569       11          6.52726          7.71013      1.89m
#    6    22.48          21.4031       53          6.52099          7.51407      1.57m
#    7    25.34          19.6536       72          6.51842          7.96595      1.16m
#    8    32.67          16.4934       57          6.48652          6.58738     41.44s
#    9    35.34          16.2405       52          6.44358          6.56873      0.00s
# SymbolicTransformer(const_range=(-1.0, 1.0), feature_names=None,
#                     function_set=['add', 'sub', 'mul', 'div', 'sin', 'cos',
#                                   'abs'],
#                     generations=10, hall_of_fame=100, init_depth=(2, 6),
#                     init_method='half and half', low_memory=False,
#                     max_samples=0.95,
#                     metric=<gplearn.fitness._Fitness object at 0x0000022F0C344E48>,
#                     n_components=10, n_jobs=1, p_crossover=0.7,
#                     p_hoist_mutation=0.05, p_point_mutation=0.01,
#                     p_point_replace=0.05, p_subtree_mutation=0.2,
#                     parsimony_coefficient=0.0005, population_size=10000,
#                     random_state=0, stopping_criteria=1.0, tournament_size=20,
#                     verbose=1, warm_start=False)

# %%
X_new = model.transform(X_train)
X_new = pd.DataFrame(X_new, index = X1.index)

# %%
X_new
# Out:
#                   0         1         2         3         4         5   \
# fecha
# 2007-01-01  0.988546  0.992925  0.985501  0.988980  0.975885  0.973842
# 2007-01-02  0.999532  0.998790  0.998018  0.999816  0.997069  0.997832
# 2007-01-03  0.983019  0.999863  0.969189  0.977655  0.997876  0.988297
# 2007-01-04  0.957519  0.989892  0.954972  0.961622  0.960064  0.988133
# 2007-01-05  0.960579  0.976661  0.964067  0.955074  0.954988  0.958679
# ...              ...       ...       ...       ...       ...       ...
# 2020-03-26  0.999993  1.000000  0.999983  0.999947  0.999980  0.999993
# 2020-03-27  0.999947  0.999947  0.999981  0.999998  0.999952  0.999977
# 2020-03-28  0.999957  0.999999  0.999985  0.999960  1.000000  0.999998
# 2020-03-29  0.999952  0.999948  0.999995  0.999948  0.999982  0.999962
# 2020-03-30  0.999965  0.999986  0.999987  0.999965  0.999962  0.999978
#
#                   6         7         8         9         10        11  \
# fecha
# 2007-01-01  0.974732  0.988227  0.977949  0.978139  0.989170  0.965701
# 2007-01-02  0.997769  0.999881  0.999682  0.999807  0.999644  0.998153
# 2007-01-03  0.964658  0.985321  0.989985  0.980968  0.982786  0.988040
# 2007-01-04  0.959887  0.984093  0.966346  0.963668  0.953216  0.963940
# 2007-01-05  0.980765  0.962252  0.955145  0.958790  0.954952  0.958775
# ...              ...       ...       ...       ...       ...       ...
# 2020-03-26  0.999963  0.999981  0.999998  0.999949  0.999947  0.999955
# 2020-03-27  0.999955  0.999990  0.999951  0.999962  0.999946  0.999999
# 2020-03-28  0.999994  0.999953  0.999993  0.999994  0.999980  0.999972
# 2020-03-29  0.999976  0.999999  0.999956  0.999986  0.999998  0.999999
# 2020-03-30  0.999952  1.000000  0.999962  1.000000  0.999948  0.999979
#
#                   12        13        14        15        16        17  \
# fecha
# 2007-01-01  0.977440  0.976941  0.987143  0.981177  0.989263  0.968596
# 2007-01-02  0.999802  1.000000  0.999912  0.998240  0.997053  0.997691
# 2007-01-03  0.978977  0.996769  0.995918  0.994891  0.984994  0.998579
# 2007-01-04  0.986161  0.989051  0.972056  0.974652  0.970970  0.964298
# 2007-01-05  0.963521  0.980521  0.962808  0.962572  0.956063  0.978446
# ...              ...       ...       ...       ...       ...       ...
# 2020-03-26  0.999975  0.999951  0.999946  0.999970  0.999947  0.999946
# 2020-03-27  0.999979  1.000000  0.999953  0.999997  0.999950  0.999981
# 2020-03-28  0.999993  0.999979  0.999958  0.999952  0.999990  0.999956
# 2020-03-29  0.999947  0.999965  0.999970  0.999958  0.999954  0.999964
# 2020-03-30  1.000000  0.999964  0.999997  1.000000  0.999992  0.999964
#
#                   18        19
# fecha
# 2007-01-01  0.980092  0.957758
# 2007-01-02  0.999943  0.998643
# 2007-01-03  0.992919  0.996523
# 2007-01-04  0.977398  0.953006
# 2007-01-05  0.981783  0.980372
# ...              ...       ...
# 2020-03-26  0.999951  0.999961
# 2020-03-27  0.999999  0.999994
# 2020-03-28  0.999995  0.999983
# 2020-03-29  0.999993  0.999955
# 2020-03-30  0.999978  0.999962
#
# [4838 rows x 20 columns]

# %%
df = pd.concat([X_new, X1], axis = 1)

# %%
df = df/df.max()

# %%
train_, test_ = train_test_split(X_norm, shuffle = False, test_size = 365)

# %% [markdown]
# ### fit

# %%
hyp = {'kernel': 'rbf',
 'C': 1.5622596668986724,
 'epsilon': 0.01,
 'mu': 0.8894683237212756,
 'lmbda': 0.7147423174236999,
 'gamma': 0.009632563464115184
      }

run = SVR_general_cvxopt(**hyp)
run.fit(train_.to_numpy(), y_train)
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# <ipython-input-233-ff3b135523b3> in <module>
#       8
#       9 run = SVR_general_cvxopt(**hyp)
# ---> 10 run.fit(train_.to_numpy(), y_train)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
pred = run.predict(train_)

# %%
pred = scaler1.inverse_transform(pred.reshape(-1, 1))

# %%
# plotting = pd.DataFrame(pred, index = y_test.index, columns = ["prediction"])
# plotting["real"] = y_test.values

# %%
plotting = pd.DataFrame(pred, index = y_train1.index, columns = ["prediction"])
plotting["real"] = scaler1.inverse_transform(y_train.reshape(-1, 1))

# %%
plotting[["real", "prediction"]].iplot()
# Out:
# <div>
#
#
#             <div id="6200afc7-e416-4730-8253-ee1d3cb0366e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6200afc7-e416-4730-8253-ee1d3cb0366e")) {
#                     Plotly.newPlot(
#                         '6200afc7-e416-4730-8253-ee1d3cb0366e',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "real", "text": "", "type": "scatter", "x": ["2007-01-01", "2007-01-02", "2007-01-03", "2007-01-04", "2007-01-05", "2007-01-06", "2007-01-07", "2007-01-08", "2007-01-09", "2007-01-10", "2007-01-11", "2007-01-12", "2007-01-13", "2007-01-14", "2007-01-15", "2007-01-16", "2007-01-17", "2007-01-18", "2007-01-19", "2007-01-20", "2007-01-21", "2007-01-22", "2007-01-23", "2007-01-24", "2007-01-25", "2007-01-26", "2007-01-27", "2007-01-28", "2007-01-29", "2007-01-30", "2007-01-31", "2007-02-01", "2007-02-02", "2007-02-03", "2007-02-04", "2007-02-05", "2007-02-06", "2007-02-07", "2007-02-08", "2007-02-09", "2007-02-10", "2007-02-11", "2007-02-12", "2007-02-13", "2007-02-14", "2007-02-15", "2007-02-16", "2007-02-17", "2007-02-18", "2007-02-19", "2007-02-20", "2007-02-21", "2007-02-22", "2007-02-23", "2007-02-24", "2007-02-25", "2007-02-26", "2007-02-27", "2007-02-28", "2007-03-01", "2007-03-02", "2007-03-03", "2007-03-04", "2007-03-05", "2007-03-06", "2007-03-07", "2007-03-08", "2007-03-09", "2007-03-10", "2007-03-11", "2007-03-12", "2007-03-13", "2007-03-14", "2007-03-15", "2007-03-16", "2007-03-17", "2007-03-18", "2007-03-19", "2007-03-20", "2007-03-21", "2007-03-22", "2007-03-23", "2007-03-24", "2007-03-25", "2007-03-26", "2007-03-27", "2007-03-28", "2007-03-29", "2007-03-30", "2007-03-31", "2007-04-01", "2007-04-02", "2007-04-03", "2007-04-04", "2007-04-05", "2007-04-06", "2007-04-07", "2007-04-08", "
019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-29", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09", "2019-11-10", "2019-11-11", "2019-11-12", "2019-11-13", "2019-11-14", "2019-11-15", "2019-11-16", "2019-11-17", "2019-11-18", "2019-11-19", "2019-11-20", "2019-11-21", "2019-11-22", "2019-11-23", "2019-11-24", "2019-11-25", "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06", "2019-12-07", "2019-12-08", "2019-12-09", "2019-12-10", "2019-12-11", "2019-12-12", "2019-12-13", "2019-12-14", "2019-12-15", "2019-12-16", "2019-12-17", "2019-12-18", "2019-12-19", "2019-12-20", "2019-12-21", "2019-12-22", "2019-12-23", "2019-12-24", "2019-12-25", "2019-12-26", "2019-12-27", "2019-12 ...

# %%
np.mean(np.abs((y_test - pred)/y_test))*100
# Out:
# MWh    5.878022
# dtype: float64

# %%
np.mean()
# Out:
# array([[129416.53293563],
#        [133105.64092507],
#        [133699.5933646 ],
#        ...,
#        [190850.81401896],
#        [173167.50688543],
#        [172937.12312732]])

# %%
bob = scaler1.inverse_transform(y_train.reshape(-1, 1))

# %%
np.mean(np.abs((bob - pred)/bob))*100
# Out:
# 4.779871727657652

# %% [markdown]
# # Load model

# %%
from pathlib import Path

# %%
path_to_model = str(Path().resolve().parent / "Models" / "GTransformer" / "GT_just_time_overfit.pkl")

# %%
with open(path_to_model, 'rb') as f:
    older = pickle.load(f)

# %%
X_new = older.transform(t_norm)
X_new = pd.DataFrame(X_new, index = X1.index)
X_new = X_new/X_new.max()

# %%
train_, test_ = train_test_split(X_new, shuffle = False, test_size = 365)

# %%
hyp = {'kernel': 'rbf',
 'C': 1.5622596668986724,
 'epsilon': 0.01,
 'mu': 0.8894683237212756,
 'lmbda': 0.7147423174236999,
 'gamma': 0.009632563464115184
      }

run = SVR_general_cvxopt(**hyp)
run.fit(train_.to_numpy(), y_train)

# %%
pred = run.predict(train_)

# %%
pred = scaler1.inverse_transform(pred.reshape(-1, 1))

# %%
plotting = pd.DataFrame(pred, index = y_train1.index, columns = ["prediction"])
plotting["real"] = scaler1.inverse_transform(y_train.reshape(-1, 1))

# %%
plotting[["real", "prediction"]].iplot()
# Out:
# <div>
#
#
#             <div id="e7e4b22f-96b5-4452-a7c9-022124cb08bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e7e4b22f-96b5-4452-a7c9-022124cb08bb")) {
#                     Plotly.newPlot(
#                         'e7e4b22f-96b5-4452-a7c9-022124cb08bb',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "real", "text": "", "type": "scatter", "x": ["2007-01-01", "2007-01-02", "2007-01-03", "2007-01-04", "2007-01-05", "2007-01-06", "2007-01-07", "2007-01-08", "2007-01-09", "2007-01-10", "2007-01-11", "2007-01-12", "2007-01-13", "2007-01-14", "2007-01-15", "2007-01-16", "2007-01-17", "2007-01-18", "2007-01-19", "2007-01-20", "2007-01-21", "2007-01-22", "2007-01-23", "2007-01-24", "2007-01-25", "2007-01-26", "2007-01-27", "2007-01-28", "2007-01-29", "2007-01-30", "2007-01-31", "2007-02-01", "2007-02-02", "2007-02-03", "2007-02-04", "2007-02-05", "2007-02-06", "2007-02-07", "2007-02-08", "2007-02-09", "2007-02-10", "2007-02-11", "2007-02-12", "2007-02-13", "2007-02-14", "2007-02-15", "2007-02-16", "2007-02-17", "2007-02-18", "2007-02-19", "2007-02-20", "2007-02-21", "2007-02-22", "2007-02-23", "2007-02-24", "2007-02-25", "2007-02-26", "2007-02-27", "2007-02-28", "2007-03-01", "2007-03-02", "2007-03-03", "2007-03-04", "2007-03-05", "2007-03-06", "2007-03-07", "2007-03-08", "2007-03-09", "2007-03-10", "2007-03-11", "2007-03-12", "2007-03-13", "2007-03-14", "2007-03-15", "2007-03-16", "2007-03-17", "2007-03-18", "2007-03-19", "2007-03