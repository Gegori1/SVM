# %% [markdown]
# # Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import MaxAbsScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle

# %%
from newgplearn.genetic import SymbolicRegressor
from newgplearn.functions import make_function

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %run ..\Function.ipynb

# %% [markdown]
# # Functions

# %% [markdown]
# ## time ones

# %%
def time(x1):
    return np.arange(1, len(x1)+1)

time = make_function(function = time,
                    name = 'time',
                    arity = 1)

def one(x1):
    return np.ones(len(x1))

one = make_function(function = one, 
                    name = 'one', 
                    arity = 1)

# %% [markdown]
# ## Trigonometric

# %%
cos_7 = make_function(function=CustomSC.cos_7, name='cos_7', arity=1)

sin_7 = make_function(function=CustomSC.sin_7, name='sin_7', arity=1)

cos_365 = make_function(function=CustomSC.cos_365, name='cos_365', arity=1)

sin_365 = make_function(function=CustomSC.sin_365, name='sin_365', arity=1)

abscos_14 = make_function(function=CustomSC.abscos_14, name='abscos_14', arity=1)

abssin_14 = make_function(function=CustomSC.abssin_14, name='abssin_14', arity=1)

# %% [markdown]
# ## month

# %%
month1 = make_function(function=Month.month1, name = 'month1', arity=1)

month2 = make_function(function=Month.month2, name = 'month2', arity=1)

month3 = make_function(function=Month.month3, name = 'month3', arity=1)

month4 = make_function(function=Month.month4, name = 'month4', arity=1)

month5 = make_function(function=Month.month5, name = 'month5', arity=1)

month6 = make_function(function=Month.month6, name = 'month6', arity=1)

month7 = make_function(function=Month.month7, name = 'month7', arity=1)

month8 = make_function(function=Month.month8, name = 'month8', arity=1)

month9 = make_function(function=Month.month9, name = 'month9', arity=1)

month10 = make_function(function=Month.month10, name = 'month10', arity=1)

month12 = make_function(function=Month.month12, name = 'month12', arity=1)

# %% [markdown]
# ## Week

# %%
# for num in range(1, 53):
#     print(f"week{num} = make_function(function=Week.week{num}, name = 'week{num}', arity=1)\n")

# %%
week1 = make_function(function=Week.week1, name = 'week1', arity=1)

week2 = make_function(function=Week.week2, name = 'week2', arity=1)

week3 = make_function(function=Week.week3, name = 'week3', arity=1)

week4 = make_function(function=Week.week4, name = 'week4', arity=1)

week5 = make_function(function=Week.week5, name = 'week5', arity=1)

week6 = make_function(function=Week.week6, name = 'week6', arity=1)

week7 = make_function(function=Week.week7, name = 'week7', arity=1)

week8 = make_function(function=Week.week8, name = 'week8', arity=1)

week9 = make_function(function=Week.week9, name = 'week9', arity=1)

week10 = make_function(function=Week.week10, name = 'week10', arity=1)

week11 = make_function(function=Week.week11, name = 'week11', arity=1)

week12 = make_function(function=Week.week12, name = 'week12', arity=1)

week13 = make_function(function=Week.week13, name = 'week13', arity=1)

week14 = make_function(function=Week.week14, name = 'week14', arity=1)

week15 = make_function(function=Week.week15, name = 'week15', arity=1)

week16 = make_function(function=Week.week16, name = 'week16', arity=1)

week17 = make_function(function=Week.week17, name = 'week17', arity=1)

week18 = make_function(function=Week.week18, name = 'week18', arity=1)

week19 = make_function(function=Week.week19, name = 'week19', arity=1)

week20 = make_function(function=Week.week20, name = 'week20', arity=1)

week21 = make_function(function=Week.week21, name = 'week21', arity=1)

week22 = make_function(function=Week.week22, name = 'week22', arity=1)

week23 = make_function(function=Week.week23, name = 'week23', arity=1)

week24 = make_function(function=Week.week24, name = 'week24', arity=1)

week25 = make_function(function=Week.week25, name = 'week25', arity=1)

week26 = make_function(function=Week.week26, name = 'week26', arity=1)

week27 = make_function(function=Week.week27, name = 'week27', arity=1)

week28 = make_function(function=Week.week28, name = 'week28', arity=1)

week29 = make_function(function=Week.week29, name = 'week29', arity=1)

week30 = make_function(function=Week.week30, name = 'week30', arity=1)

week31 = make_function(function=Week.week31, name = 'week31', arity=1)

week32 = make_function(function=Week.week32, name = 'week32', arity=1)

week33 = make_function(function=Week.week33, name = 'week33', arity=1)

week34 = make_function(function=Week.week34, name = 'week34', arity=1)

week35 = make_function(function=Week.week35, name = 'week35', arity=1)

week36 = make_function(function=Week.week36, name = 'week36', arity=1)

week37 = make_function(function=Week.week37, name = 'week37', arity=1)

week38 = make_function(function=Week.week38, name = 'week38', arity=1)

week39 = make_function(function=Week.week39, name = 'week39', arity=1)

week40 = make_function(function=Week.week40, name = 'week40', arity=1)

week41 = make_function(function=Week.week41, name = 'week41', arity=1)

week42 = make_function(function=Week.week42, name = 'week42', arity=1)

week43 = make_function(function=Week.week43, name = 'week43', arity=1)

week44 = make_function(function=Week.week44, name = 'week44', arity=1)

week45 = make_function(function=Week.week45, name = 'week45', arity=1)

week46 = make_function(function=Week.week46, name = 'week46', arity=1)

week47 = make_function(function=Week.week47, name = 'week47', arity=1)

week48 = make_function(function=Week.week48, name = 'week48', arity=1)

week49 = make_function(function=Week.week49, name = 'week49', arity=1)

week50 = make_function(function=Week.week50, name = 'week50', arity=1)

week52 = make_function(function=Week.week52, name = 'week52', arity=1)

# %% [markdown]
# ## diffuse

# %%
# for name in season:
#     print(f"{name} = make_function(function=Triangulars.{name}, name = '{name}', arity=1)\n")

# %%
winter1 = make_function(function=Triangulars.winter1, name = 'winter1', arity=1)

spring = make_function(function=Triangulars.spring, name = 'spring', arity=1)

summer = make_function(function=Triangulars.summer, name = 'summer', arity=1)

autumn1 = make_function(function=Triangulars.autumn1, name = 'autumn1', arity=1)

autumn2 = make_function(function=Triangulars.autumn2, name = 'autumn2', arity=1)

winter2 = make_function(function=Triangulars.winter2, name = 'winter2', arity=1)

# %% [markdown]
# ## Holiday

# %%
# season = "winter1","spring","summer","autumn1","autumn2","winter2"

# %%
# festivos = "DomSan","NewYear","Const","JueSan","VieSan","SabSan","Madre","Grito","Virgin1","Death","Virgin2","Christmas","ChrisEve","PreInag","Revolution","SupBowl","WCup","OldYEve","Benito","Work","Election","Oscar",

# %%
# for name in festivos:
#     print(f"{name} = make_function(function=Holiday.{name}, name = '{name}', arity=1)\n")

# %%
DomSan = make_function(function=Holiday.DomSan, name = 'DomSan', arity=1)

NewYear = make_function(function=Holiday.NewYear, name = 'NewYear', arity=1)

Const = make_function(function=Holiday.Const, name = 'Const', arity=1)

JueSan = make_function(function=Holiday.JueSan, name = 'JueSan', arity=1)

VieSan = make_function(function=Holiday.VieSan, name = 'VieSan', arity=1)

SabSan = make_function(function=Holiday.SabSan, name = 'SabSan', arity=1)

Madre = make_function(function=Holiday.Madre, name = 'Madre', arity=1)

Grito = make_function(function=Holiday.Grito, name = 'Grito', arity=1)

Virgin1 = make_function(function=Holiday.Virgin1, name = 'Virgin1', arity=1)

Death = make_function(function=Holiday.Death, name = 'Death', arity=1)

Virgin2 = make_function(function=Holiday.Virgin2, name = 'Virgin2', arity=1)

Christmas = make_function(function=Holiday.Christmas, name = 'Christmas', arity=1)

ChrisEve = make_function(function=Holiday.ChrisEve, name = 'ChrisEve', arity=1)

PreInag = make_function(function=Holiday.PreInag, name = 'PreInag', arity=1)

Revolution = make_function(function=Holiday.Revolution, name = 'Revolution', arity=1)

SupBowl = make_function(function=Holiday.SupBowl, name = 'SupBowl', arity=1)

WCup = make_function(function=Holiday.WCup, name = 'WCup', arity=1)

OldYEve = make_function(function=Holiday.OldYEve, name = 'OldYEve', arity=1)

Benito = make_function(function=Holiday.Benito, name = 'Benito', arity=1)

Work = make_function(function=Holiday.Work, name = 'Work', arity=1)

Election = make_function(function=Holiday.Election, name = 'Election', arity=1)

Oscar = make_function(function=Holiday.Oscar, name = 'Oscar', arity=1)

# %% [markdown]
# # Load data

# %%
path_consumo = Path().resolve().parents[1] / "Data" / "Data1.xlsx"
consumo = pd.read_excel(path_consumo)
consumo = consumo.set_index("fecha").loc["2007-01-01":"2020-03-30"]

# %%
t = np.arange(1, consumo.size+1).reshape(-1, 1)
day = consumo.index.dayofyear
month = consumo.index.month
year = consumo.index.year

# %%
exe = pd.DataFrame(t.reshape(-1, 1), index = consumo.index, columns = ["time"])
exe["day"] = day
exe["month"] = month
exe["year"] = year

# %%
X = pd.DataFrame(t, index = consumo.index)

# %%
# def residual(X, y):
#     X_train, X_test, y_train1, y_test1 = train_test_split(X, y, test_size = 365, shuffle = False)

#     scaler1 = MaxAbsScaler(); scaler1.fit(y_train1)
#     y_train = scaler1.transform(y_train1).reshape(-1)
#     y_test = scaler1.transform(y_test1).reshape(-1)  
#     model = LinearRegression()
#     model.fit(X_train, y_train)
#     y_predtr = model.predict(X_train)
#     y_predte = model.predict(X_test)
#     y_pred = np.hstack([y_predtr, y_predte])
#     residual_tr = y_train - y_predtr
#     residual_te = y_test - y_predte
#     residual = np.hstack([residual_tr, residual_te])
#     residual = scaler1.inverse_transform(residual.reshape(-1, 1))
#     residual = pd.DataFrame(residual, index = consumo.index, columns = ["residual"])
#     return residual, y_pred
# y_res, pred = residual(exe, consumo)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, consumo, test_size = 365, shuffle = False)

scaler = MaxAbsScaler(); scaler.fit(X_train1)
X_train = scaler.transform(X_train1)
X_test = scaler.transform(X_test1)

scaler1 = MaxAbsScaler(); scaler1.fit(y_train1)
y_train = scaler1.transform(y_train1).reshape(-1)
y_test = scaler1.transform(y_test1).reshape(-1)

# %%
function_sets = ('add', 'sub', 'mul', 'div', 'sin', 'cos', 'abs', 'log', 'neg', 'sqrt', month1, month2, month3,
                 month4, month5, month6, month7, month8, month9, month10, month12,
                 week1, week2, week3, week4, week5, week6, week7, week8, week9, week10, week11, 
                 week12, week13, week14, week15, week16, week17, week18, week19, week20, week21,
                 week22, week23, week24, week25, week26, week27, week28, week29, week30, week31, 
                 week32, week33, week34, week35, week36, week37, week38, week39, week40, week41, 
                 week42, week43, week44, week45, week46, week47, week48, week49, week50, week52,
                 cos_7, sin_7, cos_365, sin_365, abscos_14, abssin_14,
                 winter1, spring, summer, autumn1, autumn2, winter2,
                 DomSan, NewYear, Const, JueSan, VieSan, SabSan, Madre, Grito, Virgin1, Death,
                 Virgin2, Christmas, ChrisEve, PreInag, Revolution, SupBowl, WCup, OldYEve, 
                 Benito, Work, Election, Oscar,)

# %%
# /SymbolicRegressor

# %%
model = SymbolicRegressor(population_size=2000, init_method = "full",
                           p_crossover=0.5, p_subtree_mutation = 0.3, p_hoist_mutation = 0.15, warm_start = True,
                           function_set=function_sets,# feature_names = [*exe.columns],
                           max_samples = 0.95,
#                            metric = "rmse",
                           generations=50, stopping_criteria=0.01, parsimony_coefficient=0.0000005,
                           verbose=1, random_state=4)

# %%
model.fit(X_train1, y_train);
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     5.41          1.83148        5        0.0958601         0.091723     73.36m
#    1     5.47          19.5075        2        0.0748392        0.0729059     68.39m
#    2     5.24          3333.02        3        0.0741369        0.0833574     46.57m
#    3     4.30          3348.56        5        0.0740542        0.0781025     26.78m
#    4     3.03          19.4758        6        0.0741019        0.0719413     17.73m
#    5     3.15           18.241        6        0.0737848        0.0779562     15.83m
#    6     3.80          3336.06        5        0.0731275        0.0749422     17.21m
#    7     5.47           3.6017        5         0.073115        0.0751786     26.42m
# ...

# %%
print(model._program)
# Out:
# cos_7(abscos_14(div(time, year)))

# %%
# y_pred = model.predict(X_test1)
# y_pred1 = y_pred.to_numpy().reshape(-1, 1)

# %%
def pred(X, y):
    y_pred = (model.predict(X)).reshape(-1, 1)
    y_pred = scaler1.inverse_transform(y_pred)
    y_pred = pd.Series(y_pred.reshape(-1), index = X.index)
    plotting = pd.DataFrame(y_pred, columns = ["predict"])
    plotting["real"] = y
    plotting.iplot()

# %%
pred(X_train1, y_train1)
# Out:
# <div>
#
#
#             <div id="8e16dbce-9c8b-428b-b69d-4afc4a5562fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8e16dbce-9c8b-428b-b69d-4afc4a5562fc")) {
#                     Plotly.newPlot(
#                         '8e16dbce-9c8b-428b-b69d-4afc4a5562fc',
# ...

# %%
pred(X_test1, y_test1)
# Out:
# <div>
#
#
#             <div id="5815db1e-19da-4630-b2a8-79c043d8c93a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5815db1e-19da-4630-b2a8-79c043d8c93a")) {
#                     Plotly.newPlot(
#                         '5815db1e-19da-4630-b2a8-79c043d8c93a',
# ...
