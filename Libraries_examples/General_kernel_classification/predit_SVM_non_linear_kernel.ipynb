# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
 # %run SVMLibrary_generalkernel.ipynb

# %%
X, y = make_blobs(centers = 4, random_state = 2)
y = np.where(y == 2, 1, -1)

# %%
X_test = utilss.X_random(X, n_predict = 20)

# %%
model = SVM_general(C = 1, kernel= "rbf").fit(X, y)

# %%
y_predict = model.predict(X_test)

# %%
# contour plot
utilss.contour_plot(X, y, kernel = "rbf", C = 1)
# prediction
plott.scatter(X_test, y_predict, m="v")
# real values
plott.scatter(X, y, m=".")

# %% [markdown]
# # Predict train_test

# %%
 # %run SVMLibrary_generalkernel.ipynb

# %%
# create random X and y
X, y = make_blobs(centers = 2, random_state = 2, n_features = 2, cluster_std = 5);

# %%
plott.scatter(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2, test_size = 20, 
                                                    shuffle = True)

# %%
model = SVM_general(C = 0.1).fit(X_train, y_train)
# predict
y_pred = model.predict(X_test)
# coefficients
w, b = model.coef_()

# %%
f"Score: {np.mean(np.abs(y_pred - y_test))*100} %"
# Out:
# 'Score: 45.0 %'

# %%
# two features
utilss.contour_plot(X_train, y_train)
plott.scatter(X_train, y_train)
plott.scatter(X_test, y_pred, m = ".")
plott.line(X, w, b)

# %% [markdown]
# # Multiple dimensional data

# %%
 # %run SVMLibrary_generalkernel.ipynb

# %%
# create random X and y
X, y = make_blobs(centers = 2, random_state = 2, n_features = 5, cluster_std = 5);

# %%
X_test = utilss.X_random(X, n_predict = 20)

# %%
model = SVM_general(C = 0.1, kernel = "rbf").fit(X, y)
# predict
y_pred = model.predict(X_test)
# coefficients
w, x, b = model.coef_()

# %%
# ?SVM_general.predict
