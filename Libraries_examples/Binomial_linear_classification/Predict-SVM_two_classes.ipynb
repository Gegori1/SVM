# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
# SMV_linear.wb; plott.line/scatter
# %run SVC_library_2clases.ipynb

# %%
# create random X and y
X, y = make_blobs(centers = 2, random_state = 2);
# change the standar values of y
y = np.where(y == 0, 20, -105)

# %%
# test data
X_test1 = np.random.choice(np.arange(-4, 6, 0.1), 300)
X_test2 = np.random.choice(np.arange(-12, 2, 0.1), 300)
X_test = np.c_[X_test1, X_test2]

# %%
def plotting(X, y):
    # fit
    model = SVM_linear(C = 0.1).fit(X, y)
    # predict
    y_test = model.predict(X_test)
    # coefficients a and b
    w, b = model.coef_()
    # plot
    plott.scatter(X, y)
    plott.line(X, w, b)
    plott.scatter(X_test, y_test, m = ".")
    
#     print(y_test)

# %%
plotting(X, y)

# %% [markdown]
# # Contourplot

# %%
model = SVM_linear(C = 0.1).fit(X, y)
# predict
y_test = model.predict(X_test)
w, b = model.coef_()

# %%
contour_plott.color(X, y)
plott.line(X, w, b)
plott.scatter(X, y)
plott.scatter(X_test, y_test, m = ".")

# %% [markdown]
# https://nlp.stanford.edu/IR-book/html/htmledition/multiclass-svms-1.html#:~:text=It%20is%20also%20a%20simple,the%20label%20of%20structural%20SVMs%20
